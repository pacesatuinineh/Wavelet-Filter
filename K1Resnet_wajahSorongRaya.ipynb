# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Wavelet-Filter/blob/main/K1Resnet_wajahSorongRaya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import EfficientNetB5
#from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import InceptionV3
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
#data_path = "/content/drive/MyDrive/wajahPBD"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
import os

def list_folders_and_image_count(data_path):
  """
  Lists subfolders within a directory and counts the number of images in each.

  Args:
    data_path: The path to the main directory.

  Returns:
    A dictionary where keys are folder names and values are image counts.
  """
  folder_info = {}
  for folder_name in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder_name)
    if os.path.isdir(folder_path):
      image_count = 0
      for file_name in os.listdir(folder_path):
        if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
          image_count += 1
      folder_info[folder_name] = image_count
  return folder_info

# Example usage:
data_path = "/content/drive/MyDrive/WajahSorongRaya"
folder_data = list_folders_and_image_count(data_path)

# Print the results:
for folder, count in folder_data.items():
  print(f"Folder: {folder}, Image Count: {count}")
# Out:
# Folder: SorongSelatan, Image Count: 320
# Folder: Moi2, Image Count: 364
# Folder: Raja Ampat, Image Count: 337
# Folder: Maybrat, Image Count: 366

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    #haar_image = apply_haar_wavelet(image)

                    # Resize the image to 224x224 for ResNet50
                    #haar_image = cv2.resize(haar_image, (224, 224))

                    # Extract HOG features
                    #hog_features = extract_hog_features(image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)

                    #Extract Haar + Gaussia
                    #haar_image = apply_haar_wavelet_and_gaussian(image)

                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    data.append(image)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 5  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
    axes[i].imshow(image.astype(np.uint8), cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)
train_images, test_images, train_labels, test_labels = train_test_split(
    data, labels_encoded, test_size=0.2, random_state=42
)

# Split training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 887
# Jumlah data validasi: 222
# Jumlah data test: 278

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = EfficientNetB5(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    #x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    #x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
#train_images, train_labels = load_and_preprocess_images(data_path)
#test_images, test_labels = load_and_preprocess_images(data_path)


# Print the number of samples in each set
#print("Jumlah data train:", len(train_images))
#print("Jumlah data validasi:", len(val_images))
#print("Jumlah data test:", len(test_images))

# %%
# Load and preprocess all images first
all_images, all_labels = load_and_preprocess_images(data_path)

# Split into training and testing, maintaining 20% for testing
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))  # val_images remains unchanged
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 1109
# Jumlah data validasi: 222
# Jumlah data test: 278

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 102s 1s/step - accuracy: 0.3921 - loss: 13.3604 - val_accuracy: 0.5683 - val_loss: 12.4421 - learning_rate: 1.0000e-04
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.5980 - loss: 12.4056 - val_accuracy: 0.7014 - val_loss: 11.9836 - learning_rate: 1.0000e-04
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 371ms/step - accuracy: 0.7273 - loss: 11.9004 - val_accuracy: 0.7770 - val_loss: 11.6073 - learning_rate: 1.0000e-04
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 374ms/step - accuracy: 0.7274 - loss: 11.7029 - val_accuracy: 0.7770 - val_loss: 11.4625 - learning_rate: 1.0000e-04
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 361ms/step - accuracy: 0.7689 - loss: 11.3953 - val_accuracy: 0.7662 - val_loss: 11.2263 - learning_rate: 1.0000e-04
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 381ms/step - accuracy: 0.7799 - loss: 11.1444 - val_accuracy: 0.7986 - val_loss: 11.0554 - learning_rate: 1.0000e-04
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.7655 - loss: 11.0075 - val_accuracy: 0.7950 - val_loss: 10.9128 - learning_rate: 1.0000e-04
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.7871 - loss: 10.6871 - val_accuracy: 0.6942 - val_loss: 10.9662 - learning_rate: 1.0000e-04
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.7812 - loss: 10.4728 - val_accuracy: 0.8129 - val_loss: 10.3631 - learning_rate: 1.0000e-04
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 380ms/step - accuracy: 0.7735 - loss: 10.2810 - val_accuracy: 0.7842 - val_loss: 10.2542 - learning_rate: 1.0000e-04
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.8199 - loss: 10.0090 - val_accuracy: 0.7986 - val_loss: 9.9645 - learning_rate: 1.0000e-04
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.8282 - loss: 9.7597 - val_accuracy: 0.8273 - val_loss: 9.6115 - learning_rate: 1.0000e-04
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.8615 - loss: 9.4666 - val_accuracy: 0.8237 - val_loss: 9.3850 - learning_rate: 1.0000e-04
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.8437 - loss: 9.2938 - val_accuracy: 0.7878 - val_loss: 9.2672 - learning_rate: 1.0000e-04
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 369ms/step - accuracy: 0.8457 - loss: 9.0152 - val_accuracy: 0.8381 - val_loss: 8.9111 - learning_rate: 1.0000e-04
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.8329 - loss: 8.8486 - val_accuracy: 0.8381 - val_loss: 8.6556 - learning_rate: 1.0000e-04
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 365ms/step - accuracy: 0.8601 - loss: 8.5419 - val_accuracy: 0.8345 - val_loss: 8.4546 - learning_rate: 1.0000e-04
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 371ms/step - accuracy: 0.8380 - loss: 8.3525 - val_accuracy: 0.8381 - val_loss: 8.2194 - learning_rate: 1.0000e-04
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.8828 - loss: 8.0780 - val_accuracy: 0.8129 - val_loss: 8.0837 - learning_rate: 1.0000e-04
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 381ms/step - accuracy: 0.8887 - loss: 7.8643 - val_accuracy: 0.8237 - val_loss: 7.7797 - learning_rate: 1.0000e-04
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 381ms/step - accuracy: 0.9049 - loss: 7.5590 - val_accuracy: 0.8489 - val_loss: 7.6008 - learning_rate: 1.0000e-04
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 380ms/step - accuracy: 0.8804 - loss: 7.4133 - val_accuracy: 0.8129 - val_loss: 7.4927 - learning_rate: 1.0000e-04
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 375ms/step - accuracy: 0.8792 - loss: 7.1695 - val_accuracy: 0.7878 - val_loss: 7.5094 - learning_rate: 1.0000e-04
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 376ms/step - accuracy: 0.9082 - loss: 6.9041 - val_accuracy: 0.8309 - val_loss: 6.9680 - learning_rate: 1.0000e-04
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 374ms/step - accuracy: 0.8989 - loss: 6.7079 - val_accuracy: 0.8381 - val_loss: 6.7455 - learning_rate: 1.0000e-04
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.9148 - loss: 6.4528 - val_accuracy: 0.8669 - val_loss: 6.4887 - learning_rate: 1.0000e-04
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 389ms/step - accuracy: 0.9332 - loss: 6.2259 - val_accuracy: 0.8453 - val_loss: 6.3791 - learning_rate: 1.0000e-04
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.9108 - loss: 6.0736 - val_accuracy: 0.8022 - val_loss: 6.2711 - learning_rate: 1.0000e-04
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 375ms/step - accuracy: 0.9205 - loss: 5.8524 - val_accuracy: 0.8165 - val_loss: 6.2187 - learning_rate: 1.0000e-04
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 375ms/step - accuracy: 0.9345 - loss: 5.6192 - val_accuracy: 0.8309 - val_loss: 5.8881 - learning_rate: 1.0000e-04
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 379ms/step - accuracy: 0.9461 - loss: 5.4074 - val_accuracy: 0.7914 - val_loss: 5.8870 - learning_rate: 1.0000e-04
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 376ms/step - accuracy: 0.9428 - loss: 5.2291 - val_accuracy: 0.8309 - val_loss: 5.6751 - learning_rate: 1.0000e-04
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.9317 - loss: 5.0783 - val_accuracy: 0.8597 - val_loss: 5.2498 - learning_rate: 1.0000e-04
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 379ms/step - accuracy: 0.9345 - loss: 4.8724 - val_accuracy: 0.8561 - val_loss: 5.1689 - learning_rate: 1.0000e-04
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 385ms/step - accuracy: 0.9358 - loss: 4.7050 - val_accuracy: 0.8453 - val_loss: 4.9517 - learning_rate: 1.0000e-04
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.9458 - loss: 4.5160 - val_accuracy: 0.8417 - val_loss: 4.9127 - learning_rate: 1.0000e-04
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 376ms/step - accuracy: 0.9502 - loss: 4.3442 - val_accuracy: 0.8453 - val_loss: 4.7350 - learning_rate: 1.0000e-04
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 365ms/step - accuracy: 0.9306 - loss: 4.2100 - val_accuracy: 0.8237 - val_loss: 4.6684 - learning_rate: 1.0000e-04
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.9507 - loss: 4.0414 - val_accuracy: 0.8345 - val_loss: 4.4302 - learning_rate: 1.0000e-04
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 369ms/step - accuracy: 0.9311 - loss: 3.9033 - val_accuracy: 0.7950 - val_loss: 4.5150 - learning_rate: 1.0000e-04
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 393ms/step - accuracy: 0.9614 - loss: 3.6985 - val_accuracy: 0.8309 - val_loss: 4.2533 - learning_rate: 1.0000e-04
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.9752 - loss: 3.5224 - val_accuracy: 0.8561 - val_loss: 3.9043 - learning_rate: 1.0000e-04
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 376ms/step - accuracy: 0.9509 - loss: 3.4364 - val_accuracy: 0.8345 - val_loss: 3.7557 - learning_rate: 1.0000e-04
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 365ms/step - accuracy: 0.9599 - loss: 3.2896 - val_accuracy: 0.8058 - val_loss: 3.9051 - learning_rate: 1.0000e-04
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.9685 - loss: 3.1172 - val_accuracy: 0.8129 - val_loss: 3.6718 - learning_rate: 1.0000e-04
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 382ms/step - accuracy: 0.9495 - loss: 3.0226 - val_accuracy: 0.8201 - val_loss: 3.7157 - learning_rate: 1.0000e-04
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 386ms/step - accuracy: 0.9613 - loss: 2.8859 - val_accuracy: 0.8381 - val_loss: 3.2079 - learning_rate: 1.0000e-04
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 371ms/step - accuracy: 0.9657 - loss: 2.7662 - val_accuracy: 0.8453 - val_loss: 3.1356 - learning_rate: 1.0000e-04
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 386ms/step - accuracy: 0.9664 - loss: 2.6328 - val_accuracy: 0.8273 - val_loss: 3.0858 - learning_rate: 1.0000e-04
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.9604 - loss: 2.5259 - val_accuracy: 0.8453 - val_loss: 2.8189 - learning_rate: 1.0000e-04
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 371ms/step - accuracy: 0.9684 - loss: 2.4263 - val_accuracy: 0.8094 - val_loss: 2.9523 - learning_rate: 1.0000e-04
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 375ms/step - accuracy: 0.9760 - loss: 2.2878 - val_accuracy: 0.8417 - val_loss: 2.7142 - learning_rate: 1.0000e-04
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.9709 - loss: 2.2060 - val_accuracy: 0.8489 - val_loss: 2.7013 - learning_rate: 1.0000e-04
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 363ms/step - accuracy: 0.9720 - loss: 2.0903 - val_accuracy: 0.7950 - val_loss: 3.2645 - learning_rate: 1.0000e-04
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.9501 - loss: 2.0519 - val_accuracy: 0.8489 - val_loss: 2.4421 - learning_rate: 1.0000e-04
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.9560 - loss: 1.9528 - val_accuracy: 0.8813 - val_loss: 2.2407 - learning_rate: 1.0000e-04
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 372ms/step - accuracy: 0.9780 - loss: 1.8280 - val_accuracy: 0.8741 - val_loss: 2.1629 - learning_rate: 1.0000e-04
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 375ms/step - accuracy: 0.9570 - loss: 1.7676 - val_accuracy: 0.8453 - val_loss: 2.1627 - learning_rate: 1.0000e-04
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 365ms/step - accuracy: 0.9562 - loss: 1.7059 - val_accuracy: 0.7554 - val_loss: 2.5362 - learning_rate: 1.0000e-04
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 371ms/step - accuracy: 0.9713 - loss: 1.5915 - val_accuracy: 0.8273 - val_loss: 2.2427 - learning_rate: 1.0000e-04
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.9606 - loss: 1.5712 - val_accuracy: 0.8597 - val_loss: 1.9930 - learning_rate: 1.0000e-04
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.9772 - loss: 1.4406 - val_accuracy: 0.8417 - val_loss: 1.9682 - learning_rate: 1.0000e-04
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 401ms/step - accuracy: 0.9670 - loss: 1.3833 - val_accuracy: 0.8525 - val_loss: 1.8055 - learning_rate: 1.0000e-04
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 381ms/step - accuracy: 0.9771 - loss: 1.3201 - val_accuracy: 0.8489 - val_loss: 1.8897 - learning_rate: 1.0000e-04
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.9731 - loss: 1.2645 - val_accuracy: 0.8129 - val_loss: 1.7991 - learning_rate: 1.0000e-04
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.9771 - loss: 1.1871 - val_accuracy: 0.8381 - val_loss: 1.9121 - learning_rate: 1.0000e-04
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.9758 - loss: 1.1389 - val_accuracy: 0.8237 - val_loss: 1.8211 - learning_rate: 1.0000e-04
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 362ms/step - accuracy: 0.9778 - loss: 1.0801 - val_accuracy: 0.8094 - val_loss: 2.0006 - learning_rate: 1.0000e-04
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 374ms/step - accuracy: 0.9715 - loss: 1.0464 - val_accuracy: 0.8345 - val_loss: 1.6729 - learning_rate: 1.0000e-04
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 371ms/step - accuracy: 0.9645 - loss: 1.0087 - val_accuracy: 0.8273 - val_loss: 1.5805 - learning_rate: 1.0000e-04
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.9646 - loss: 0.9757 - val_accuracy: 0.8705 - val_loss: 1.4244 - learning_rate: 1.0000e-04
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 380ms/step - accuracy: 0.9788 - loss: 0.9051 - val_accuracy: 0.8165 - val_loss: 1.4796 - learning_rate: 1.0000e-04
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.9747 - loss: 0.8734 - val_accuracy: 0.8381 - val_loss: 1.3935 - learning_rate: 1.0000e-04
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 388ms/step - accuracy: 0.9786 - loss: 0.8089 - val_accuracy: 0.8561 - val_loss: 1.3392 - learning_rate: 1.0000e-04
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 386ms/step - accuracy: 0.9673 - loss: 0.7979 - val_accuracy: 0.8094 - val_loss: 1.3701 - learning_rate: 1.0000e-04
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 376ms/step - accuracy: 0.9770 - loss: 0.7431 - val_accuracy: 0.8417 - val_loss: 1.3693 - learning_rate: 1.0000e-04
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 374ms/step - accuracy: 0.9750 - loss: 0.7154 - val_accuracy: 0.8345 - val_loss: 1.3504 - learning_rate: 1.0000e-04
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.9859 - loss: 0.6634 - val_accuracy: 0.8417 - val_loss: 1.3910 - learning_rate: 1.0000e-04
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.9674 - loss: 0.6793 - val_accuracy: 0.8309 - val_loss: 1.3016 - learning_rate: 1.0000e-04
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 372ms/step - accuracy: 0.9845 - loss: 0.6071 - val_accuracy: 0.8453 - val_loss: 1.0862 - learning_rate: 1.0000e-04
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.9883 - loss: 0.5768 - val_accuracy: 0.8453 - val_loss: 1.2679 - learning_rate: 1.0000e-04
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.9823 - loss: 0.5612 - val_accuracy: 0.8165 - val_loss: 1.2697 - learning_rate: 1.0000e-04
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.9847 - loss: 0.5352 - val_accuracy: 0.7914 - val_loss: 1.2266 - learning_rate: 1.0000e-04
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.9785 - loss: 0.5124 - val_accuracy: 0.8309 - val_loss: 1.4341 - learning_rate: 1.0000e-04
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.9719 - loss: 0.4913 - val_accuracy: 0.7914 - val_loss: 1.0857 - learning_rate: 1.0000e-04
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.9758 - loss: 0.4643 - val_accuracy: 0.8417 - val_loss: 0.9588 - learning_rate: 1.0000e-04
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 368ms/step - accuracy: 0.9812 - loss: 0.4554 - val_accuracy: 0.8417 - val_loss: 1.0004 - learning_rate: 1.0000e-04
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 377ms/step - accuracy: 0.9580 - loss: 0.4853 - val_accuracy: 0.8561 - val_loss: 0.9794 - learning_rate: 1.0000e-04
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 367ms/step - accuracy: 0.9817 - loss: 0.4088 - val_accuracy: 0.8813 - val_loss: 0.8156 - learning_rate: 1.0000e-04
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.9837 - loss: 0.3754 - val_accuracy: 0.8525 - val_loss: 1.0212 - learning_rate: 1.0000e-04
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.9809 - loss: 0.3956 - val_accuracy: 0.8309 - val_loss: 1.1153 - learning_rate: 1.0000e-04
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 376ms/step - accuracy: 0.9700 - loss: 0.4037 - val_accuracy: 0.7806 - val_loss: 1.3962 - learning_rate: 1.0000e-04
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 365ms/step - accuracy: 0.9840 - loss: 0.3427 - val_accuracy: 0.8525 - val_loss: 0.9068 - learning_rate: 1.0000e-04
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 376ms/step - accuracy: 0.9785 - loss: 0.3473 - val_accuracy: 0.8453 - val_loss: 0.8285 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 224, 224, 3))
#   warnings.warn(msg)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 492ms/step
#                precision    recall  f1-score   support
#
#       Maybrat       0.84      0.70      0.77        70
#          Moi2       1.00      0.97      0.98        67
#    Raja Ampat       0.92      1.00      0.96        79
# SorongSelatan       0.75      0.84      0.79        62
#
#      accuracy                           0.88       278
#     macro avg       0.88      0.88      0.88       278
#  weighted avg       0.88      0.88      0.88       278
