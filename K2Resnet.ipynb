# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Wavelet-Filter/blob/main/K2Resnet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
#from tensorflow.keras.applications import EfficientNetB0
#from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import InceptionV3
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
#data_path = "/content/drive/MyDrive/datasetObjective"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
import os

def list_folders_and_image_count(data_path):
  """
  Lists subfolders within a directory and counts the number of images in each.

  Args:
    data_path: The path to the main directory.

  Returns:
    A dictionary where keys are folder names and values are image counts.
  """
  folder_info = {}
  for folder_name in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder_name)
    if os.path.isdir(folder_path):
      image_count = 0
      for file_name in os.listdir(folder_path):
        if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
          image_count += 1
      folder_info[folder_name] = image_count
  return folder_info

# Example usage:
data_path = "/content/drive/MyDrive/datasetObjective"
folder_data = list_folders_and_image_count(data_path)

# Print the results:
for folder, count in folder_data.items():
  print(f"Folder: {folder}, Image Count: {count}")
# Out:
# Folder: Moi, Image Count: 549
# Folder: Aitinyo, Image Count: 500
# Folder: Ayamaru, Image Count: 500
# Folder: Kokoda, Image Count: 400
# Folder: Tehit, Image Count: 495

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    haar_image = apply_haar_wavelet(image)

                    # Resize the image to 224x224 for ResNet50
                    haar_image = cv2.resize(haar_image, (224, 224))

                    # Extract HOG features
                    #hog_features = extract_hog_features(image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)

                    #Extract Haar + Gaussia
                    #haar_image = apply_haar_wavelet_and_gaussian(image)

                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    data.append(haar_image)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 5  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
    axes[i].imshow(image.astype(np.uint8), cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)
train_images, test_images, train_labels, test_labels = train_test_split(
    data, labels_encoded, test_size=0.2, random_state=42
)

# Split training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 1564
# Jumlah data validasi: 391
# Jumlah data test: 489

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    #x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    #x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
#train_images, train_labels = load_and_preprocess_images(data_path)
#test_images, test_labels = load_and_preprocess_images(data_path)


# Print the number of samples in each set
#print("Jumlah data train:", len(train_images))
#print("Jumlah data validasi:", len(val_images))
#print("Jumlah data test:", len(test_images))

# %%
# Load and preprocess all images first
all_images, all_labels = load_and_preprocess_images(data_path)

# Split into training and testing, maintaining 20% for testing
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))  # val_images remains unchanged
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 1955
# Jumlah data validasi: 391
# Jumlah data test: 489

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 127s 891ms/step - accuracy: 0.2373 - loss: 13.9643 - val_accuracy: 0.2986 - val_loss: 12.9427 - learning_rate: 1.0000e-04
# Epoch 2/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 363ms/step - accuracy: 0.3140 - loss: 13.2846 - val_accuracy: 0.3333 - val_loss: 12.7516 - learning_rate: 1.0000e-04
# Epoch 3/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 367ms/step - accuracy: 0.3713 - loss: 12.8524 - val_accuracy: 0.4274 - val_loss: 12.2907 - learning_rate: 1.0000e-04
# Epoch 4/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.3786 - loss: 12.4377 - val_accuracy: 0.4581 - val_loss: 11.9617 - learning_rate: 1.0000e-04
# Epoch 5/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 361ms/step - accuracy: 0.4076 - loss: 12.1046 - val_accuracy: 0.4540 - val_loss: 11.7425 - learning_rate: 1.0000e-04
# Epoch 6/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 365ms/step - accuracy: 0.4542 - loss: 11.7238 - val_accuracy: 0.4949 - val_loss: 11.3608 - learning_rate: 1.0000e-04
# Epoch 7/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 362ms/step - accuracy: 0.4630 - loss: 11.4812 - val_accuracy: 0.4847 - val_loss: 11.1687 - learning_rate: 1.0000e-04
# Epoch 8/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 362ms/step - accuracy: 0.4782 - loss: 11.1298 - val_accuracy: 0.4785 - val_loss: 10.9675 - learning_rate: 1.0000e-04
# Epoch 9/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 363ms/step - accuracy: 0.5142 - loss: 10.8001 - val_accuracy: 0.5092 - val_loss: 10.5927 - learning_rate: 1.0000e-04
# Epoch 10/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 363ms/step - accuracy: 0.4976 - loss: 10.5431 - val_accuracy: 0.5603 - val_loss: 10.1920 - learning_rate: 1.0000e-04
# Epoch 11/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 363ms/step - accuracy: 0.5007 - loss: 10.2649 - val_accuracy: 0.5665 - val_loss: 9.9080 - learning_rate: 1.0000e-04
# Epoch 12/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.5481 - loss: 9.9350 - val_accuracy: 0.5215 - val_loss: 9.9395 - learning_rate: 1.0000e-04
# Epoch 13/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 366ms/step - accuracy: 0.5586 - loss: 9.6836 - val_accuracy: 0.5542 - val_loss: 9.4485 - learning_rate: 1.0000e-04
# Epoch 14/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 364ms/step - accuracy: 0.5764 - loss: 9.3564 - val_accuracy: 0.5092 - val_loss: 9.4030 - learning_rate: 1.0000e-04
# Epoch 15/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 366ms/step - accuracy: 0.5826 - loss: 9.1171 - val_accuracy: 0.5828 - val_loss: 8.9225 - learning_rate: 1.0000e-04
# Epoch 16/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 363ms/step - accuracy: 0.5780 - loss: 8.8610 - val_accuracy: 0.5665 - val_loss: 8.7622 - learning_rate: 1.0000e-04
# Epoch 17/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 354ms/step - accuracy: 0.5914 - loss: 8.5872 - val_accuracy: 0.6012 - val_loss: 8.3846 - learning_rate: 1.0000e-04
# Epoch 18/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.6178 - loss: 8.2975 - val_accuracy: 0.6196 - val_loss: 8.1710 - learning_rate: 1.0000e-04
# Epoch 19/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 354ms/step - accuracy: 0.5727 - loss: 8.1226 - val_accuracy: 0.5481 - val_loss: 7.9739 - learning_rate: 1.0000e-04
# Epoch 20/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 352ms/step - accuracy: 0.6188 - loss: 7.8515 - val_accuracy: 0.4560 - val_loss: 8.1842 - learning_rate: 1.0000e-04
# Epoch 21/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 354ms/step - accuracy: 0.6058 - loss: 7.6234 - val_accuracy: 0.5378 - val_loss: 7.6424 - learning_rate: 1.0000e-04
# Epoch 22/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.6289 - loss: 7.2919 - val_accuracy: 0.6217 - val_loss: 7.2161 - learning_rate: 1.0000e-04
# Epoch 23/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 359ms/step - accuracy: 0.6500 - loss: 7.0950 - val_accuracy: 0.6217 - val_loss: 6.9699 - learning_rate: 1.0000e-04
# Epoch 24/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 353ms/step - accuracy: 0.6723 - loss: 6.8203 - val_accuracy: 0.6339 - val_loss: 6.7952 - learning_rate: 1.0000e-04
# Epoch 25/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 362ms/step - accuracy: 0.6767 - loss: 6.5833 - val_accuracy: 0.6503 - val_loss: 6.5582 - learning_rate: 1.0000e-04
# Epoch 26/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.6746 - loss: 6.3765 - val_accuracy: 0.5787 - val_loss: 6.5028 - learning_rate: 1.0000e-04
# Epoch 27/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 354ms/step - accuracy: 0.6930 - loss: 6.1104 - val_accuracy: 0.5992 - val_loss: 6.2349 - learning_rate: 1.0000e-04
# Epoch 28/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 362ms/step - accuracy: 0.6972 - loss: 5.9032 - val_accuracy: 0.5849 - val_loss: 6.0877 - learning_rate: 1.0000e-04
# Epoch 29/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 360ms/step - accuracy: 0.7062 - loss: 5.7027 - val_accuracy: 0.6115 - val_loss: 5.7547 - learning_rate: 1.0000e-04
# Epoch 30/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 363ms/step - accuracy: 0.6975 - loss: 5.5137 - val_accuracy: 0.6033 - val_loss: 5.6282 - learning_rate: 1.0000e-04
# Epoch 31/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 364ms/step - accuracy: 0.6909 - loss: 5.3222 - val_accuracy: 0.5890 - val_loss: 5.4599 - learning_rate: 1.0000e-04
# Epoch 32/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 370ms/step - accuracy: 0.7257 - loss: 5.0981 - val_accuracy: 0.6155 - val_loss: 5.2369 - learning_rate: 1.0000e-04
# Epoch 33/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 374ms/step - accuracy: 0.7107 - loss: 4.9596 - val_accuracy: 0.6442 - val_loss: 5.0229 - learning_rate: 1.0000e-04
# Epoch 34/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 26s 370ms/step - accuracy: 0.7298 - loss: 4.7123 - val_accuracy: 0.5706 - val_loss: 5.1156 - learning_rate: 1.0000e-04
# Epoch 35/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 26s 367ms/step - accuracy: 0.7219 - loss: 4.5896 - val_accuracy: 0.6217 - val_loss: 4.6776 - learning_rate: 1.0000e-04
# Epoch 36/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 363ms/step - accuracy: 0.7518 - loss: 4.3841 - val_accuracy: 0.5072 - val_loss: 5.0937 - learning_rate: 1.0000e-04
# Epoch 37/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 370ms/step - accuracy: 0.7303 - loss: 4.2458 - val_accuracy: 0.6278 - val_loss: 4.4196 - learning_rate: 1.0000e-04
# Epoch 38/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 359ms/step - accuracy: 0.7656 - loss: 3.9976 - val_accuracy: 0.6176 - val_loss: 4.4641 - learning_rate: 1.0000e-04
# Epoch 39/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 365ms/step - accuracy: 0.7476 - loss: 3.9460 - val_accuracy: 0.6421 - val_loss: 4.1913 - learning_rate: 1.0000e-04
# Epoch 40/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 365ms/step - accuracy: 0.7678 - loss: 3.7190 - val_accuracy: 0.5910 - val_loss: 4.2780 - learning_rate: 1.0000e-04
# Epoch 41/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 364ms/step - accuracy: 0.7453 - loss: 3.6453 - val_accuracy: 0.5481 - val_loss: 4.0592 - learning_rate: 1.0000e-04
# Epoch 42/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 365ms/step - accuracy: 0.7534 - loss: 3.4964 - val_accuracy: 0.5930 - val_loss: 3.8237 - learning_rate: 1.0000e-04
# Epoch 43/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 362ms/step - accuracy: 0.7873 - loss: 3.2880 - val_accuracy: 0.6094 - val_loss: 3.8135 - learning_rate: 1.0000e-04
# Epoch 44/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 360ms/step - accuracy: 0.8029 - loss: 3.1302 - val_accuracy: 0.5624 - val_loss: 3.8738 - learning_rate: 1.0000e-04
# Epoch 45/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 26s 374ms/step - accuracy: 0.7875 - loss: 3.0599 - val_accuracy: 0.5706 - val_loss: 3.8074 - learning_rate: 1.0000e-04
# Epoch 46/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 26s 369ms/step - accuracy: 0.7890 - loss: 2.8991 - val_accuracy: 0.6176 - val_loss: 3.5296 - learning_rate: 1.0000e-04
# Epoch 47/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 26s 367ms/step - accuracy: 0.8014 - loss: 2.8262 - val_accuracy: 0.6155 - val_loss: 3.4792 - learning_rate: 1.0000e-04
# Epoch 48/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 363ms/step - accuracy: 0.8016 - loss: 2.6968 - val_accuracy: 0.6380 - val_loss: 3.1733 - learning_rate: 1.0000e-04
# Epoch 49/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.8108 - loss: 2.6169 - val_accuracy: 0.5869 - val_loss: 3.1780 - learning_rate: 1.0000e-04
# Epoch 50/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.7920 - loss: 2.4967 - val_accuracy: 0.5992 - val_loss: 3.0410 - learning_rate: 1.0000e-04
# Epoch 51/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.7882 - loss: 2.4376 - val_accuracy: 0.5358 - val_loss: 3.5566 - learning_rate: 1.0000e-04
# Epoch 52/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 359ms/step - accuracy: 0.8181 - loss: 2.2670 - val_accuracy: 0.5951 - val_loss: 3.0869 - learning_rate: 1.0000e-04
# Epoch 53/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 359ms/step - accuracy: 0.8380 - loss: 2.1452 - val_accuracy: 0.5787 - val_loss: 3.2746 - learning_rate: 1.0000e-04
# Epoch 54/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 357ms/step - accuracy: 0.8190 - loss: 2.1227 - val_accuracy: 0.5726 - val_loss: 3.0208 - learning_rate: 1.0000e-04
# Epoch 55/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8362 - loss: 2.0268 - val_accuracy: 0.6012 - val_loss: 2.9702 - learning_rate: 1.0000e-04
# Epoch 56/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 354ms/step - accuracy: 0.8172 - loss: 1.9244 - val_accuracy: 0.6135 - val_loss: 2.5426 - learning_rate: 1.0000e-04
# Epoch 57/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 351ms/step - accuracy: 0.8330 - loss: 1.8600 - val_accuracy: 0.5992 - val_loss: 2.6685 - learning_rate: 1.0000e-04
# Epoch 58/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 350ms/step - accuracy: 0.8320 - loss: 1.7760 - val_accuracy: 0.5726 - val_loss: 2.6494 - learning_rate: 1.0000e-04
# Epoch 59/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 351ms/step - accuracy: 0.8404 - loss: 1.7005 - val_accuracy: 0.6401 - val_loss: 2.4988 - learning_rate: 1.0000e-04
# Epoch 60/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 356ms/step - accuracy: 0.8352 - loss: 1.6398 - val_accuracy: 0.6319 - val_loss: 2.4182 - learning_rate: 1.0000e-04
# Epoch 61/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 353ms/step - accuracy: 0.8292 - loss: 1.5784 - val_accuracy: 0.5521 - val_loss: 3.0475 - learning_rate: 1.0000e-04
# Epoch 62/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 351ms/step - accuracy: 0.8466 - loss: 1.4912 - val_accuracy: 0.5481 - val_loss: 2.6968 - learning_rate: 1.0000e-04
# Epoch 63/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 353ms/step - accuracy: 0.8668 - loss: 1.3894 - val_accuracy: 0.5849 - val_loss: 2.2979 - learning_rate: 1.0000e-04
# Epoch 64/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 354ms/step - accuracy: 0.8567 - loss: 1.3769 - val_accuracy: 0.5644 - val_loss: 2.5830 - learning_rate: 1.0000e-04
# Epoch 65/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 351ms/step - accuracy: 0.8774 - loss: 1.2777 - val_accuracy: 0.5930 - val_loss: 2.3548 - learning_rate: 1.0000e-04
# Epoch 66/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 352ms/step - accuracy: 0.8952 - loss: 1.2183 - val_accuracy: 0.5215 - val_loss: 2.8976 - learning_rate: 1.0000e-04
# Epoch 67/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 360ms/step - accuracy: 0.8648 - loss: 1.2386 - val_accuracy: 0.6401 - val_loss: 2.1790 - learning_rate: 1.0000e-04
# Epoch 68/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 349ms/step - accuracy: 0.8853 - loss: 1.1253 - val_accuracy: 0.6053 - val_loss: 2.3835 - learning_rate: 1.0000e-04
# Epoch 69/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 353ms/step - accuracy: 0.8669 - loss: 1.1096 - val_accuracy: 0.5992 - val_loss: 2.1698 - learning_rate: 1.0000e-04
# Epoch 70/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 350ms/step - accuracy: 0.8774 - loss: 1.0922 - val_accuracy: 0.6258 - val_loss: 2.3207 - learning_rate: 1.0000e-04
# Epoch 71/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 353ms/step - accuracy: 0.8758 - loss: 1.0167 - val_accuracy: 0.5337 - val_loss: 2.5002 - learning_rate: 1.0000e-04
# Epoch 72/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 350ms/step - accuracy: 0.8616 - loss: 1.0414 - val_accuracy: 0.4335 - val_loss: 3.6402 - learning_rate: 1.0000e-04
# Epoch 73/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 358ms/step - accuracy: 0.8636 - loss: 0.9946 - val_accuracy: 0.5808 - val_loss: 1.8777 - learning_rate: 1.0000e-04
# Epoch 74/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 355ms/step - accuracy: 0.8612 - loss: 0.9357 - val_accuracy: 0.5992 - val_loss: 2.0612 - learning_rate: 1.0000e-04
# Epoch 75/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 354ms/step - accuracy: 0.8802 - loss: 0.8912 - val_accuracy: 0.6135 - val_loss: 2.0883 - learning_rate: 1.0000e-04
# Epoch 76/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 353ms/step - accuracy: 0.8924 - loss: 0.8593 - val_accuracy: 0.5297 - val_loss: 3.8385 - learning_rate: 1.0000e-04
# Epoch 77/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 24s 355ms/step - accuracy: 0.8548 - loss: 0.9119 - val_accuracy: 0.5624 - val_loss: 2.2336 - learning_rate: 1.0000e-04
# Epoch 78/100
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 25s 353ms/step - accuracy: 0.8880 - loss: 0.7968 - val_accuracy: 0.4888 - val_loss: 2.8125 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 8s 285ms/step
#               precision    recall  f1-score   support
#
#      Aitinyo       0.56      0.43      0.48        94
#      Ayamaru       0.54      0.49      0.51       106
#       Kokoda       0.88      0.76      0.81        87
#          Moi       0.62      0.57      0.59       115
#        Tehit       0.43      0.69      0.53        87
#
#     accuracy                           0.58       489
#    macro avg       0.61      0.59      0.59       489
# weighted avg       0.60      0.58      0.58       489
