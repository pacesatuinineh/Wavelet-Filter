# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Wavelet-Filter/blob/main/K2Resnet_wajahSorongRaya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import EfficientNetB5
#from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import InceptionV3
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
#data_path = "/content/drive/MyDrive/wajahPBD"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
import os

def list_folders_and_image_count(data_path):
  """
  Lists subfolders within a directory and counts the number of images in each.

  Args:
    data_path: The path to the main directory.

  Returns:
    A dictionary where keys are folder names and values are image counts.
  """
  folder_info = {}
  for folder_name in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder_name)
    if os.path.isdir(folder_path):
      image_count = 0
      for file_name in os.listdir(folder_path):
        if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
          image_count += 1
      folder_info[folder_name] = image_count
  return folder_info

# Example usage:
data_path = "/content/drive/MyDrive/WajahSorongRaya"
folder_data = list_folders_and_image_count(data_path)

# Print the results:
for folder, count in folder_data.items():
  print(f"Folder: {folder}, Image Count: {count}")
# Out:
# Folder: SorongSelatan, Image Count: 320
# Folder: Moi2, Image Count: 364
# Folder: Raja Ampat, Image Count: 337
# Folder: Maybrat, Image Count: 366

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    haar_image = apply_haar_wavelet(image)

                    # Resize the image to 224x224 for ResNet50
                    haar_image = cv2.resize(haar_image, (224, 224))

                    # Extract HOG features
                    #hog_features = extract_hog_features(image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)

                    #Extract Haar + Gaussia
                    #haar_image = apply_haar_wavelet_and_gaussian(image)

                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    data.append(haar_image)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 5  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
    axes[i].imshow(image.astype(np.uint8), cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)
train_images, test_images, train_labels, test_labels = train_test_split(
    data, labels_encoded, test_size=0.2, random_state=42
)

# Split training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 887
# Jumlah data validasi: 222
# Jumlah data test: 278

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = EfficientNetB5(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    #x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    #x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
#train_images, train_labels = load_and_preprocess_images(data_path)
#test_images, test_labels = load_and_preprocess_images(data_path)


# Print the number of samples in each set
#print("Jumlah data train:", len(train_images))
#print("Jumlah data validasi:", len(val_images))
#print("Jumlah data test:", len(test_images))

# %%
# Load and preprocess all images first
all_images, all_labels = load_and_preprocess_images(data_path)

# Split into training and testing, maintaining 20% for testing
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))  # val_images remains unchanged
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 1109
# Jumlah data validasi: 222
# Jumlah data test: 278

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 115s 1s/step - accuracy: 0.3188 - loss: 13.7600 - val_accuracy: 0.3345 - val_loss: 12.7639 - learning_rate: 1.0000e-04
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 421ms/step - accuracy: 0.5979 - loss: 12.5971 - val_accuracy: 0.4604 - val_loss: 12.4965 - learning_rate: 1.0000e-04
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 426ms/step - accuracy: 0.6249 - loss: 12.2944 - val_accuracy: 0.6439 - val_loss: 11.9990 - learning_rate: 1.0000e-04
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 425ms/step - accuracy: 0.7223 - loss: 11.9012 - val_accuracy: 0.7050 - val_loss: 11.8171 - learning_rate: 1.0000e-04
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 438ms/step - accuracy: 0.7279 - loss: 11.6798 - val_accuracy: 0.7518 - val_loss: 11.5287 - learning_rate: 1.0000e-04
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 427ms/step - accuracy: 0.7389 - loss: 11.3837 - val_accuracy: 0.7590 - val_loss: 11.2866 - learning_rate: 1.0000e-04
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 425ms/step - accuracy: 0.7798 - loss: 11.1507 - val_accuracy: 0.7914 - val_loss: 11.0219 - learning_rate: 1.0000e-04
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 430ms/step - accuracy: 0.7789 - loss: 11.0190 - val_accuracy: 0.8022 - val_loss: 10.7978 - learning_rate: 1.0000e-04
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 426ms/step - accuracy: 0.8099 - loss: 10.7046 - val_accuracy: 0.8201 - val_loss: 10.6553 - learning_rate: 1.0000e-04
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 436ms/step - accuracy: 0.7905 - loss: 10.5748 - val_accuracy: 0.8165 - val_loss: 10.6130 - learning_rate: 1.0000e-04
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 426ms/step - accuracy: 0.8283 - loss: 10.3021 - val_accuracy: 0.8273 - val_loss: 10.2491 - learning_rate: 1.0000e-04
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 426ms/step - accuracy: 0.8391 - loss: 10.0758 - val_accuracy: 0.8094 - val_loss: 10.0956 - learning_rate: 1.0000e-04
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 422ms/step - accuracy: 0.8364 - loss: 9.8761 - val_accuracy: 0.8417 - val_loss: 9.9508 - learning_rate: 1.0000e-04
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 421ms/step - accuracy: 0.8522 - loss: 9.6632 - val_accuracy: 0.8489 - val_loss: 9.6086 - learning_rate: 1.0000e-04
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 421ms/step - accuracy: 0.8325 - loss: 9.5258 - val_accuracy: 0.7806 - val_loss: 9.6352 - learning_rate: 1.0000e-04
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 432ms/step - accuracy: 0.8745 - loss: 9.2672 - val_accuracy: 0.8058 - val_loss: 9.2808 - learning_rate: 1.0000e-04
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 441ms/step - accuracy: 0.8742 - loss: 9.0414 - val_accuracy: 0.8273 - val_loss: 9.0519 - learning_rate: 1.0000e-04
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 437ms/step - accuracy: 0.8660 - loss: 8.8270 - val_accuracy: 0.8022 - val_loss: 9.0890 - learning_rate: 1.0000e-04
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 442ms/step - accuracy: 0.8608 - loss: 8.6166 - val_accuracy: 0.8453 - val_loss: 8.6571 - learning_rate: 1.0000e-04
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 435ms/step - accuracy: 0.9067 - loss: 8.3949 - val_accuracy: 0.7770 - val_loss: 8.9108 - learning_rate: 1.0000e-04
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 438ms/step - accuracy: 0.8990 - loss: 8.2005 - val_accuracy: 0.7914 - val_loss: 8.6818 - learning_rate: 1.0000e-04
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 455ms/step - accuracy: 0.8848 - loss: 7.9871 - val_accuracy: 0.8058 - val_loss: 8.3630 - learning_rate: 1.0000e-04
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 446ms/step - accuracy: 0.9145 - loss: 7.7532 - val_accuracy: 0.8381 - val_loss: 7.9312 - learning_rate: 1.0000e-04
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 438ms/step - accuracy: 0.8913 - loss: 7.5898 - val_accuracy: 0.8201 - val_loss: 7.9894 - learning_rate: 1.0000e-04
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 17s 467ms/step - accuracy: 0.9288 - loss: 7.3289 - val_accuracy: 0.8273 - val_loss: 7.6219 - learning_rate: 1.0000e-04
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 443ms/step - accuracy: 0.9341 - loss: 7.1425 - val_accuracy: 0.8022 - val_loss: 7.7350 - learning_rate: 1.0000e-04
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 443ms/step - accuracy: 0.9215 - loss: 6.9673 - val_accuracy: 0.7950 - val_loss: 7.6507 - learning_rate: 1.0000e-04
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 441ms/step - accuracy: 0.9176 - loss: 6.8127 - val_accuracy: 0.7914 - val_loss: 7.2980 - learning_rate: 1.0000e-04
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 442ms/step - accuracy: 0.9142 - loss: 6.5969 - val_accuracy: 0.8525 - val_loss: 6.8114 - learning_rate: 1.0000e-04
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 447ms/step - accuracy: 0.9492 - loss: 6.3640 - val_accuracy: 0.8489 - val_loss: 6.7800 - learning_rate: 1.0000e-04
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 453ms/step - accuracy: 0.9442 - loss: 6.1823 - val_accuracy: 0.8417 - val_loss: 6.5694 - learning_rate: 1.0000e-04
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 453ms/step - accuracy: 0.9278 - loss: 6.0299 - val_accuracy: 0.8417 - val_loss: 6.3801 - learning_rate: 1.0000e-04
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 442ms/step - accuracy: 0.9316 - loss: 5.8534 - val_accuracy: 0.7878 - val_loss: 6.3844 - learning_rate: 1.0000e-04
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 438ms/step - accuracy: 0.9436 - loss: 5.6397 - val_accuracy: 0.8129 - val_loss: 6.0472 - learning_rate: 1.0000e-04
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 455ms/step - accuracy: 0.9502 - loss: 5.5113 - val_accuracy: 0.8129 - val_loss: 5.9574 - learning_rate: 1.0000e-04
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 456ms/step - accuracy: 0.9354 - loss: 5.3323 - val_accuracy: 0.8309 - val_loss: 5.8546 - learning_rate: 1.0000e-04
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 446ms/step - accuracy: 0.9563 - loss: 5.1161 - val_accuracy: 0.8669 - val_loss: 5.3890 - learning_rate: 1.0000e-04
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 446ms/step - accuracy: 0.9539 - loss: 4.9807 - val_accuracy: 0.8094 - val_loss: 5.4958 - learning_rate: 1.0000e-04
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 442ms/step - accuracy: 0.9504 - loss: 4.8053 - val_accuracy: 0.8237 - val_loss: 5.2056 - learning_rate: 1.0000e-04
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 459ms/step - accuracy: 0.9704 - loss: 4.6201 - val_accuracy: 0.8417 - val_loss: 5.0899 - learning_rate: 1.0000e-04
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 458ms/step - accuracy: 0.9616 - loss: 4.4701 - val_accuracy: 0.7842 - val_loss: 5.1745 - learning_rate: 1.0000e-04
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 451ms/step - accuracy: 0.9537 - loss: 4.3537 - val_accuracy: 0.7662 - val_loss: 4.8819 - learning_rate: 1.0000e-04
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 451ms/step - accuracy: 0.9495 - loss: 4.2056 - val_accuracy: 0.8129 - val_loss: 4.6800 - learning_rate: 1.0000e-04
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 436ms/step - accuracy: 0.9609 - loss: 4.0372 - val_accuracy: 0.8237 - val_loss: 4.5650 - learning_rate: 1.0000e-04
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 453ms/step - accuracy: 0.9621 - loss: 3.8904 - val_accuracy: 0.8525 - val_loss: 4.2543 - learning_rate: 1.0000e-04
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 437ms/step - accuracy: 0.9655 - loss: 3.7845 - val_accuracy: 0.8094 - val_loss: 4.1591 - learning_rate: 1.0000e-04
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 461ms/step - accuracy: 0.9534 - loss: 3.6512 - val_accuracy: 0.8165 - val_loss: 4.1443 - learning_rate: 1.0000e-04
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 436ms/step - accuracy: 0.9553 - loss: 3.4919 - val_accuracy: 0.7878 - val_loss: 4.1883 - learning_rate: 1.0000e-04
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 447ms/step - accuracy: 0.9438 - loss: 3.3894 - val_accuracy: 0.7878 - val_loss: 4.0360 - learning_rate: 1.0000e-04
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 457ms/step - accuracy: 0.9626 - loss: 3.2143 - val_accuracy: 0.8201 - val_loss: 3.7133 - learning_rate: 1.0000e-04
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 447ms/step - accuracy: 0.9507 - loss: 3.1325 - val_accuracy: 0.8453 - val_loss: 3.5676 - learning_rate: 1.0000e-04
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 452ms/step - accuracy: 0.9463 - loss: 3.0343 - val_accuracy: 0.8345 - val_loss: 3.4514 - learning_rate: 1.0000e-04
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 440ms/step - accuracy: 0.9576 - loss: 2.8998 - val_accuracy: 0.8489 - val_loss: 3.2461 - learning_rate: 1.0000e-04
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 441ms/step - accuracy: 0.9526 - loss: 2.8133 - val_accuracy: 0.7986 - val_loss: 3.3145 - learning_rate: 1.0000e-04
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 450ms/step - accuracy: 0.9768 - loss: 2.6297 - val_accuracy: 0.8237 - val_loss: 3.0873 - learning_rate: 1.0000e-04
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 455ms/step - accuracy: 0.9735 - loss: 2.5604 - val_accuracy: 0.8094 - val_loss: 3.3192 - learning_rate: 1.0000e-04
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 444ms/step - accuracy: 0.9679 - loss: 2.4403 - val_accuracy: 0.8381 - val_loss: 2.8683 - learning_rate: 1.0000e-04
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 446ms/step - accuracy: 0.9845 - loss: 2.3213 - val_accuracy: 0.8165 - val_loss: 2.8311 - learning_rate: 1.0000e-04
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 438ms/step - accuracy: 0.9797 - loss: 2.2507 - val_accuracy: 0.8237 - val_loss: 2.7007 - learning_rate: 1.0000e-04
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 423ms/step - accuracy: 0.9662 - loss: 2.1796 - val_accuracy: 0.8309 - val_loss: 2.6101 - learning_rate: 1.0000e-04
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 441ms/step - accuracy: 0.9782 - loss: 2.0778 - val_accuracy: 0.8597 - val_loss: 2.5041 - learning_rate: 1.0000e-04
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 434ms/step - accuracy: 0.9705 - loss: 1.9853 - val_accuracy: 0.8525 - val_loss: 2.4293 - learning_rate: 1.0000e-04
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 441ms/step - accuracy: 0.9631 - loss: 1.9446 - val_accuracy: 0.8741 - val_loss: 2.1956 - learning_rate: 1.0000e-04
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 437ms/step - accuracy: 0.9742 - loss: 1.8269 - val_accuracy: 0.8453 - val_loss: 2.4519 - learning_rate: 1.0000e-04
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 433ms/step - accuracy: 0.9641 - loss: 1.7659 - val_accuracy: 0.8777 - val_loss: 2.0351 - learning_rate: 1.0000e-04
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 427ms/step - accuracy: 0.9845 - loss: 1.6480 - val_accuracy: 0.8561 - val_loss: 2.0374 - learning_rate: 1.0000e-04
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 437ms/step - accuracy: 0.9796 - loss: 1.5932 - val_accuracy: 0.8489 - val_loss: 2.0558 - learning_rate: 1.0000e-04
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 462ms/step - accuracy: 0.9842 - loss: 1.5053 - val_accuracy: 0.8561 - val_loss: 1.9760 - learning_rate: 1.0000e-04
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 436ms/step - accuracy: 0.9642 - loss: 1.4967 - val_accuracy: 0.8237 - val_loss: 1.9410 - learning_rate: 1.0000e-04
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 450ms/step - accuracy: 0.9695 - loss: 1.4189 - val_accuracy: 0.8381 - val_loss: 2.0215 - learning_rate: 1.0000e-04
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 453ms/step - accuracy: 0.9620 - loss: 1.3821 - val_accuracy: 0.8561 - val_loss: 1.7186 - learning_rate: 1.0000e-04
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 457ms/step - accuracy: 0.9775 - loss: 1.2722 - val_accuracy: 0.8453 - val_loss: 1.6896 - learning_rate: 1.0000e-04
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 433ms/step - accuracy: 0.9715 - loss: 1.2372 - val_accuracy: 0.8525 - val_loss: 1.7338 - learning_rate: 1.0000e-04
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 449ms/step - accuracy: 0.9699 - loss: 1.1959 - val_accuracy: 0.8381 - val_loss: 1.8459 - learning_rate: 1.0000e-04
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 431ms/step - accuracy: 0.9727 - loss: 1.1257 - val_accuracy: 0.8597 - val_loss: 1.6746 - learning_rate: 1.0000e-04
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 440ms/step - accuracy: 0.9759 - loss: 1.0856 - val_accuracy: 0.7950 - val_loss: 2.1197 - learning_rate: 1.0000e-04
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 425ms/step - accuracy: 0.9651 - loss: 1.0558 - val_accuracy: 0.8094 - val_loss: 1.9941 - learning_rate: 1.0000e-04
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 425ms/step - accuracy: 0.9743 - loss: 0.9839 - val_accuracy: 0.8381 - val_loss: 1.7129 - learning_rate: 1.0000e-04
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 437ms/step - accuracy: 0.9771 - loss: 0.9186 - val_accuracy: 0.8489 - val_loss: 1.5402 - learning_rate: 1.0000e-04
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 459ms/step - accuracy: 0.9675 - loss: 0.9285 - val_accuracy: 0.8417 - val_loss: 1.3914 - learning_rate: 1.0000e-04
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 431ms/step - accuracy: 0.9718 - loss: 0.8690 - val_accuracy: 0.8381 - val_loss: 1.4056 - learning_rate: 1.0000e-04
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 451ms/step - accuracy: 0.9634 - loss: 0.8541 - val_accuracy: 0.8309 - val_loss: 1.4504 - learning_rate: 1.0000e-04
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 446ms/step - accuracy: 0.9711 - loss: 0.8025 - val_accuracy: 0.8453 - val_loss: 1.4164 - learning_rate: 1.0000e-04
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 440ms/step - accuracy: 0.9780 - loss: 0.7501 - val_accuracy: 0.8525 - val_loss: 1.3708 - learning_rate: 1.0000e-04
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 432ms/step - accuracy: 0.9834 - loss: 0.7015 - val_accuracy: 0.8345 - val_loss: 1.3127 - learning_rate: 1.0000e-04
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 445ms/step - accuracy: 0.9756 - loss: 0.6841 - val_accuracy: 0.8309 - val_loss: 1.3750 - learning_rate: 1.0000e-04
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 433ms/step - accuracy: 0.9740 - loss: 0.6449 - val_accuracy: 0.8453 - val_loss: 1.3159 - learning_rate: 1.0000e-04
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 436ms/step - accuracy: 0.9778 - loss: 0.6452 - val_accuracy: 0.8094 - val_loss: 1.2498 - learning_rate: 1.0000e-04
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 448ms/step - accuracy: 0.9755 - loss: 0.5916 - val_accuracy: 0.8237 - val_loss: 1.2488 - learning_rate: 1.0000e-04
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 436ms/step - accuracy: 0.9855 - loss: 0.5618 - val_accuracy: 0.8165 - val_loss: 1.3684 - learning_rate: 1.0000e-04
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 432ms/step - accuracy: 0.9890 - loss: 0.5213 - val_accuracy: 0.8381 - val_loss: 1.1002 - learning_rate: 1.0000e-04
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 432ms/step - accuracy: 0.9774 - loss: 0.5300 - val_accuracy: 0.8094 - val_loss: 1.3139 - learning_rate: 1.0000e-04
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 433ms/step - accuracy: 0.9761 - loss: 0.5069 - val_accuracy: 0.8022 - val_loss: 1.4313 - learning_rate: 1.0000e-04
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 428ms/step - accuracy: 0.9817 - loss: 0.4662 - val_accuracy: 0.8309 - val_loss: 1.2966 - learning_rate: 1.0000e-04
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 434ms/step - accuracy: 0.9840 - loss: 0.4523 - val_accuracy: 0.8417 - val_loss: 1.0395 - learning_rate: 1.0000e-04
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 432ms/step - accuracy: 0.9721 - loss: 0.4419 - val_accuracy: 0.8094 - val_loss: 1.2191 - learning_rate: 1.0000e-04
# Epoch 97/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 431ms/step - accuracy: 0.9736 - loss: 0.4421 - val_accuracy: 0.8561 - val_loss: 1.0358 - learning_rate: 1.0000e-04
# Epoch 98/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 443ms/step - accuracy: 0.9841 - loss: 0.4170 - val_accuracy: 0.8381 - val_loss: 0.9639 - learning_rate: 1.0000e-04
# Epoch 99/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 433ms/step - accuracy: 0.9865 - loss: 0.3711 - val_accuracy: 0.8669 - val_loss: 0.9406 - learning_rate: 1.0000e-04
# Epoch 100/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 16s 445ms/step - accuracy: 0.9778 - loss: 0.3872 - val_accuracy: 0.8309 - val_loss: 0.9683 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 224, 224, 3))
#   warnings.warn(msg)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 549ms/step
#                precision    recall  f1-score   support
#
#       Maybrat       0.78      0.74      0.76        70
#          Moi2       1.00      0.94      0.97        67
#    Raja Ampat       0.92      1.00      0.96        79
# SorongSelatan       0.76      0.76      0.76        62
#
#      accuracy                           0.87       278
#     macro avg       0.86      0.86      0.86       278
#  weighted avg       0.87      0.87      0.87       278
