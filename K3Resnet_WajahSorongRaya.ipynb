# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Wavelet-Filter/blob/main/K3Resnet_WajahSorongRaya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3
# !pip install PyWavelets
# Out:
# Collecting PyWavelets
#   Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from PyWavelets) (2.0.2)
# Downloading pywavelets-1.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 33.2 MB/s eta 0:00:00
# Installing collected packages: PyWavelets
# Successfully installed PyWavelets-1.8.0

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import EfficientNetB0
#from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np
import pywt

import random
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
#data_path = "/content/drive/MyDrive/modifdataset"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
import os

def list_folders_and_image_count(data_path):
  """
  Lists subfolders within a directory and counts the number of images in each.

  Args:
    data_path: The path to the main directory.

  Returns:
    A dictionary where keys are folder names and values are image counts.
  """
  folder_info = {}
  for folder_name in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder_name)
    if os.path.isdir(folder_path):
      image_count = 0
      for file_name in os.listdir(folder_path):
        if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
          image_count += 1
      folder_info[folder_name] = image_count
  return folder_info

# Example usage:
data_path = "/content/drive/MyDrive/WajahSorongRaya"
folder_data = list_folders_and_image_count(data_path)

# Print the results:
for folder, count in folder_data.items():
  print(f"Folder: {folder}, Image Count: {count}")
# Out:
# Folder: SorongSelatan, Image Count: 320
# Folder: Moi2, Image Count: 364
# Folder: Raja Ampat, Image Count: 337
# Folder: Maybrat, Image Count: 366

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    #haar_image = apply_haar_wavelet(image)

                    #Resize the image to 224x224 for ResNet50
                    ##haar_image = apply_haar_wavelet_and_gaussian(haar_image)

                    # Extract HOG features
                    #hog_features = extract_hog_features(haar_image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)


                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    # 1. Gaussian Smoothing
                    gaussian_image = cv2.GaussianBlur(image, (5, 5), 0)

                    # 2. Haar Wavelet (Modified for 3 channels)
                    haar_image_LL = apply_haar_wavelet_and_gaussian(gaussian_image[:,:,0]) #Channel R
                    haar_image_LH = apply_haar_wavelet_and_gaussian(gaussian_image[:,:,1]) #Channel G
                    haar_image_HL = apply_haar_wavelet_and_gaussian(gaussian_image[:,:,2]) #Channel B
                    haar_image = np.stack([haar_image_LL,haar_image_LH, haar_image_HL], axis=-1)
                    haar_image = cv2.resize(haar_image.astype(np.uint8), IMAGE_SIZE)

                    # 3. HOG Features (on the 3-channel Haar output)
                    hog_features = extract_hog_features(haar_image)

                    data.append(hog_features)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 4  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
#fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
#for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
#    axes[i].imshow(image.astype(np.uint8), cmap='gray')
#    axes[i].axis('off')
#    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
#plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
#from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)
train_images, test_images, train_labels, test_labels = train_test_split(
    data, labels_encoded, test_size=0.2, random_state=42
)

# Split training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 887
# Jumlah data validasi: 222
# Jumlah data test: 278

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    #x = Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    #x = Dropout(0.5)(x)

    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
#train_images, train_labels = load_and_preprocess_images(data_path)
#test_images, test_labels = load_and_preprocess_images(data_path)
# Load and preprocess all images first
all_images, all_labels = load_and_preprocess_images(data_path)

# Split into training and testing, maintaining 20% for testing
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))  # val_images remains unchanged
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 1109
# Jumlah data validasi: 222
# Jumlah data test: 278

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 0.2572 - loss: 15.9747 - val_accuracy: 0.2734 - val_loss: 14.8675 - learning_rate: 1.0000e-05
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 416ms/step - accuracy: 0.2816 - loss: 15.7694 - val_accuracy: 0.3345 - val_loss: 14.7259 - learning_rate: 1.0000e-05
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.2898 - loss: 15.6057 - val_accuracy: 0.4281 - val_loss: 14.6088 - learning_rate: 1.0000e-05
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 387ms/step - accuracy: 0.3078 - loss: 15.4854 - val_accuracy: 0.4928 - val_loss: 14.4974 - learning_rate: 1.0000e-05
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 419ms/step - accuracy: 0.3289 - loss: 15.4468 - val_accuracy: 0.5396 - val_loss: 14.3932 - learning_rate: 1.0000e-05
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 428ms/step - accuracy: 0.3251 - loss: 15.3091 - val_accuracy: 0.5863 - val_loss: 14.3006 - learning_rate: 1.0000e-05
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 402ms/step - accuracy: 0.3127 - loss: 15.4097 - val_accuracy: 0.6151 - val_loss: 14.2204 - learning_rate: 1.0000e-05
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 406ms/step - accuracy: 0.3748 - loss: 15.0995 - val_accuracy: 0.6367 - val_loss: 14.1526 - learning_rate: 1.0000e-05
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.3852 - loss: 15.0600 - val_accuracy: 0.6475 - val_loss: 14.0655 - learning_rate: 1.0000e-05
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.3888 - loss: 14.9450 - val_accuracy: 0.6511 - val_loss: 14.0023 - learning_rate: 1.0000e-05
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 398ms/step - accuracy: 0.4265 - loss: 14.9034 - val_accuracy: 0.6511 - val_loss: 13.9474 - learning_rate: 1.0000e-05
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.4353 - loss: 14.8118 - val_accuracy: 0.6583 - val_loss: 13.9131 - learning_rate: 1.0000e-05
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 389ms/step - accuracy: 0.4399 - loss: 14.7915 - val_accuracy: 0.6691 - val_loss: 13.8992 - learning_rate: 1.0000e-05
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 395ms/step - accuracy: 0.4873 - loss: 14.5966 - val_accuracy: 0.6763 - val_loss: 13.8575 - learning_rate: 1.0000e-05
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.4519 - loss: 14.6727 - val_accuracy: 0.7050 - val_loss: 13.8130 - learning_rate: 1.0000e-05
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 398ms/step - accuracy: 0.4645 - loss: 14.6582 - val_accuracy: 0.7374 - val_loss: 13.7577 - learning_rate: 1.0000e-05
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 406ms/step - accuracy: 0.5018 - loss: 14.4786 - val_accuracy: 0.7518 - val_loss: 13.7062 - learning_rate: 1.0000e-05
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.5088 - loss: 14.4606 - val_accuracy: 0.7446 - val_loss: 13.6726 - learning_rate: 1.0000e-05
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 392ms/step - accuracy: 0.4917 - loss: 14.4498 - val_accuracy: 0.7554 - val_loss: 13.6254 - learning_rate: 1.0000e-05
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 401ms/step - accuracy: 0.5515 - loss: 14.3139 - val_accuracy: 0.7734 - val_loss: 13.5850 - learning_rate: 1.0000e-05
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.5231 - loss: 14.3690 - val_accuracy: 0.7842 - val_loss: 13.5456 - learning_rate: 1.0000e-05
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 386ms/step - accuracy: 0.5743 - loss: 14.1884 - val_accuracy: 0.7950 - val_loss: 13.5161 - learning_rate: 1.0000e-05
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 396ms/step - accuracy: 0.5500 - loss: 14.2780 - val_accuracy: 0.8022 - val_loss: 13.4869 - learning_rate: 1.0000e-05
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.5843 - loss: 14.1474 - val_accuracy: 0.8094 - val_loss: 13.4631 - learning_rate: 1.0000e-05
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 396ms/step - accuracy: 0.5702 - loss: 14.1124 - val_accuracy: 0.8273 - val_loss: 13.4414 - learning_rate: 1.0000e-05
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 378ms/step - accuracy: 0.5545 - loss: 14.1212 - val_accuracy: 0.8129 - val_loss: 13.4272 - learning_rate: 1.0000e-05
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.6133 - loss: 14.0723 - val_accuracy: 0.8094 - val_loss: 13.3941 - learning_rate: 1.0000e-05
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.6003 - loss: 13.9702 - val_accuracy: 0.7986 - val_loss: 13.3782 - learning_rate: 1.0000e-05
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.6279 - loss: 13.9474 - val_accuracy: 0.7950 - val_loss: 13.3735 - learning_rate: 1.0000e-05
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 387ms/step - accuracy: 0.6061 - loss: 13.9312 - val_accuracy: 0.8129 - val_loss: 13.3466 - learning_rate: 1.0000e-05
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.6204 - loss: 13.9805 - val_accuracy: 0.8165 - val_loss: 13.3303 - learning_rate: 1.0000e-05
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 402ms/step - accuracy: 0.6091 - loss: 13.8732 - val_accuracy: 0.8201 - val_loss: 13.3233 - learning_rate: 1.0000e-05
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 410ms/step - accuracy: 0.6055 - loss: 13.9265 - val_accuracy: 0.8237 - val_loss: 13.3102 - learning_rate: 1.0000e-05
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 413ms/step - accuracy: 0.6445 - loss: 13.7773 - val_accuracy: 0.8237 - val_loss: 13.2949 - learning_rate: 1.0000e-05
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 422ms/step - accuracy: 0.6398 - loss: 13.7415 - val_accuracy: 0.8237 - val_loss: 13.2797 - learning_rate: 1.0000e-05
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.6177 - loss: 13.7658 - val_accuracy: 0.8201 - val_loss: 13.2897 - learning_rate: 1.0000e-05
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 409ms/step - accuracy: 0.6327 - loss: 13.7007 - val_accuracy: 0.8381 - val_loss: 13.2516 - learning_rate: 1.0000e-05
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.6718 - loss: 13.6177 - val_accuracy: 0.8381 - val_loss: 13.2268 - learning_rate: 1.0000e-05
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 383ms/step - accuracy: 0.6356 - loss: 13.6753 - val_accuracy: 0.8345 - val_loss: 13.2184 - learning_rate: 1.0000e-05
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.6756 - loss: 13.5981 - val_accuracy: 0.8273 - val_loss: 13.1913 - learning_rate: 1.0000e-05
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 385ms/step - accuracy: 0.7116 - loss: 13.4664 - val_accuracy: 0.8237 - val_loss: 13.1808 - learning_rate: 1.0000e-05
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.6685 - loss: 13.5542 - val_accuracy: 0.8201 - val_loss: 13.1681 - learning_rate: 1.0000e-05
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 388ms/step - accuracy: 0.7233 - loss: 13.4841 - val_accuracy: 0.8165 - val_loss: 13.1790 - learning_rate: 1.0000e-05
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 407ms/step - accuracy: 0.6972 - loss: 13.4751 - val_accuracy: 0.8058 - val_loss: 13.1688 - learning_rate: 1.0000e-05
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 379ms/step - accuracy: 0.6799 - loss: 13.4985 - val_accuracy: 0.8165 - val_loss: 13.1193 - learning_rate: 1.0000e-05
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.6687 - loss: 13.4798 - val_accuracy: 0.8201 - val_loss: 13.1054 - learning_rate: 1.0000e-05
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 392ms/step - accuracy: 0.7057 - loss: 13.3974 - val_accuracy: 0.8201 - val_loss: 13.0885 - learning_rate: 1.0000e-05
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 383ms/step - accuracy: 0.7005 - loss: 13.4282 - val_accuracy: 0.7842 - val_loss: 13.0911 - learning_rate: 1.0000e-05
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 395ms/step - accuracy: 0.7202 - loss: 13.2994 - val_accuracy: 0.8165 - val_loss: 13.0635 - learning_rate: 1.0000e-05
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.6999 - loss: 13.3667 - val_accuracy: 0.7986 - val_loss: 13.0515 - learning_rate: 1.0000e-05
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.7029 - loss: 13.3893 - val_accuracy: 0.8022 - val_loss: 13.0430 - learning_rate: 1.0000e-05
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 387ms/step - accuracy: 0.7303 - loss: 13.2506 - val_accuracy: 0.8094 - val_loss: 13.0103 - learning_rate: 1.0000e-05
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 389ms/step - accuracy: 0.7421 - loss: 13.2332 - val_accuracy: 0.8201 - val_loss: 12.9850 - learning_rate: 1.0000e-05
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 385ms/step - accuracy: 0.7296 - loss: 13.1562 - val_accuracy: 0.8058 - val_loss: 12.9825 - learning_rate: 1.0000e-05
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 387ms/step - accuracy: 0.7319 - loss: 13.2079 - val_accuracy: 0.7986 - val_loss: 12.9680 - learning_rate: 1.0000e-05
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.7090 - loss: 13.1971 - val_accuracy: 0.8129 - val_loss: 12.9513 - learning_rate: 1.0000e-05
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 405ms/step - accuracy: 0.6949 - loss: 13.2591 - val_accuracy: 0.8058 - val_loss: 12.9392 - learning_rate: 1.0000e-05
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 400ms/step - accuracy: 0.7236 - loss: 13.1687 - val_accuracy: 0.8165 - val_loss: 12.8978 - learning_rate: 1.0000e-05
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 388ms/step - accuracy: 0.7268 - loss: 13.1449 - val_accuracy: 0.8129 - val_loss: 12.8833 - learning_rate: 1.0000e-05
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 393ms/step - accuracy: 0.7340 - loss: 13.1345 - val_accuracy: 0.7914 - val_loss: 12.8891 - learning_rate: 1.0000e-05
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.7355 - loss: 13.0583 - val_accuracy: 0.7914 - val_loss: 12.8708 - learning_rate: 1.0000e-05
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 404ms/step - accuracy: 0.7333 - loss: 12.9861 - val_accuracy: 0.8129 - val_loss: 12.8448 - learning_rate: 1.0000e-05
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 378ms/step - accuracy: 0.7445 - loss: 13.0087 - val_accuracy: 0.7986 - val_loss: 12.8452 - learning_rate: 1.0000e-05
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.7509 - loss: 12.9692 - val_accuracy: 0.7734 - val_loss: 12.8615 - learning_rate: 1.0000e-05
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.7211 - loss: 12.9873 - val_accuracy: 0.8273 - val_loss: 12.7727 - learning_rate: 1.0000e-05
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 380ms/step - accuracy: 0.7522 - loss: 12.9730 - val_accuracy: 0.8165 - val_loss: 12.7835 - learning_rate: 1.0000e-05
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 383ms/step - accuracy: 0.7297 - loss: 12.9874 - val_accuracy: 0.8058 - val_loss: 12.7588 - learning_rate: 1.0000e-05
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.7482 - loss: 12.8562 - val_accuracy: 0.8129 - val_loss: 12.7285 - learning_rate: 1.0000e-05
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 401ms/step - accuracy: 0.7508 - loss: 12.9005 - val_accuracy: 0.8201 - val_loss: 12.7054 - learning_rate: 1.0000e-05
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.7760 - loss: 12.7493 - val_accuracy: 0.8201 - val_loss: 12.6692 - learning_rate: 1.0000e-05
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 409ms/step - accuracy: 0.7607 - loss: 12.8017 - val_accuracy: 0.8273 - val_loss: 12.6460 - learning_rate: 1.0000e-05
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 402ms/step - accuracy: 0.7691 - loss: 12.7930 - val_accuracy: 0.8237 - val_loss: 12.6138 - learning_rate: 1.0000e-05
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 370ms/step - accuracy: 0.7483 - loss: 12.7782 - val_accuracy: 0.8058 - val_loss: 12.6399 - learning_rate: 1.0000e-05
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 375ms/step - accuracy: 0.7705 - loss: 12.6998 - val_accuracy: 0.8129 - val_loss: 12.6083 - learning_rate: 1.0000e-05
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 392ms/step - accuracy: 0.8090 - loss: 12.6123 - val_accuracy: 0.8165 - val_loss: 12.5925 - learning_rate: 1.0000e-05
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.7771 - loss: 12.6851 - val_accuracy: 0.8237 - val_loss: 12.5538 - learning_rate: 1.0000e-05
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 393ms/step - accuracy: 0.7683 - loss: 12.6228 - val_accuracy: 0.8165 - val_loss: 12.5388 - learning_rate: 1.0000e-05
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 380ms/step - accuracy: 0.7669 - loss: 12.6364 - val_accuracy: 0.8165 - val_loss: 12.5297 - learning_rate: 1.0000e-05
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 393ms/step - accuracy: 0.7774 - loss: 12.6023 - val_accuracy: 0.8129 - val_loss: 12.5153 - learning_rate: 1.0000e-05
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.7853 - loss: 12.5690 - val_accuracy: 0.8058 - val_loss: 12.5090 - learning_rate: 1.0000e-05
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 402ms/step - accuracy: 0.7605 - loss: 12.6106 - val_accuracy: 0.8201 - val_loss: 12.4652 - learning_rate: 1.0000e-05
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.7975 - loss: 12.5329 - val_accuracy: 0.7950 - val_loss: 12.4968 - learning_rate: 1.0000e-05
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 403ms/step - accuracy: 0.8074 - loss: 12.4939 - val_accuracy: 0.7914 - val_loss: 12.4440 - learning_rate: 1.0000e-05
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 401ms/step - accuracy: 0.8030 - loss: 12.4597 - val_accuracy: 0.8489 - val_loss: 12.3527 - learning_rate: 1.0000e-05
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.8189 - loss: 12.3702 - val_accuracy: 0.8489 - val_loss: 12.3485 - learning_rate: 1.0000e-05
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.7952 - loss: 12.3968 - val_accuracy: 0.7914 - val_loss: 12.3862 - learning_rate: 1.0000e-05
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.8401 - loss: 12.3047 - val_accuracy: 0.8129 - val_loss: 12.3433 - learning_rate: 1.0000e-05
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.8193 - loss: 12.3212 - val_accuracy: 0.8094 - val_loss: 12.2989 - learning_rate: 1.0000e-05
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.8121 - loss: 12.3096 - val_accuracy: 0.8129 - val_loss: 12.2803 - learning_rate: 1.0000e-05
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.8390 - loss: 12.2523 - val_accuracy: 0.8201 - val_loss: 12.2807 - learning_rate: 1.0000e-05
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 392ms/step - accuracy: 0.8071 - loss: 12.2803 - val_accuracy: 0.8165 - val_loss: 12.2758 - learning_rate: 1.0000e-05
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.8086 - loss: 12.2450 - val_accuracy: 0.8417 - val_loss: 12.2002 - learning_rate: 1.0000e-05
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.8351 - loss: 12.1655 - val_accuracy: 0.8345 - val_loss: 12.1848 - learning_rate: 1.0000e-05
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 393ms/step - accuracy: 0.8251 - loss: 12.1373 - val_accuracy: 0.8273 - val_loss: 12.1794 - learning_rate: 1.0000e-05
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 388ms/step - accuracy: 0.8347 - loss: 12.1208 - val_accuracy: 0.8345 - val_loss: 12.1564 - learning_rate: 1.0000e-05
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.8463 - loss: 12.0525 - val_accuracy: 0.8381 - val_loss: 12.1289 - learning_rate: 1.0000e-05
# Epoch 97/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 383ms/step - accuracy: 0.8412 - loss: 12.0710 - val_accuracy: 0.8309 - val_loss: 12.0834 - learning_rate: 1.0000e-05
# Epoch 98/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 400ms/step - accuracy: 0.8330 - loss: 12.0422 - val_accuracy: 0.8417 - val_loss: 12.0623 - learning_rate: 1.0000e-05
# Epoch 99/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 392ms/step - accuracy: 0.8484 - loss: 12.0227 - val_accuracy: 0.8345 - val_loss: 12.0965 - learning_rate: 1.0000e-05
# Epoch 100/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 378ms/step - accuracy: 0.8704 - loss: 11.9674 - val_accuracy: 0.8273 - val_loss: 12.0896 - learning_rate: 1.0000e-05

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 224, 224, 3))
#   warnings.warn(msg)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 481ms/step
#                precision    recall  f1-score   support
#
#       Maybrat       0.71      0.70      0.71        70
#          Moi2       0.98      0.97      0.98        67
#    Raja Ampat       0.93      0.99      0.96        79
# SorongSelatan       0.71      0.68      0.69        62
#
#      accuracy                           0.84       278
#     macro avg       0.83      0.83      0.83       278
#  weighted avg       0.84      0.84      0.84       278

# %%
import random
import matplotlib.pyplot as plt
import numpy as np

random_index = random.randint(0, len(test_images) - 1)
image = test_images[random_index]
true_label = test_labels[random_index]

prediction = model.predict(np.expand_dims(image, axis=0))[0]
predicted_class_index = np.argmax(prediction)
predicted_class_label = encoder.classes_[predicted_class_index]
confidence = prediction[predicted_class_index]
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
plt.imshow(image)
plt.title(f"True Label: {true_label}\nPredicted Label: {predicted_class_label}\nConfidence: {confidence:.2f}")
plt.axis('off')
plt.show()
